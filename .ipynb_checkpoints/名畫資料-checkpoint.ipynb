# %%
import mysql.connector
import base64
import io
import PIL.Image

line_split = "------------------------------------------------"
line_new = "\n"

# 設定資料庫連線資訊
mydb = mysql.connector.connect(
        host="127.0.0.1",port=3307, # mysql 的主機ip
        #host="127.0.0.1",port=3306, # mysql 的主機ip
        user="root",	  # mysql 的 username
        password="",	  # mysql 的password
        database="arts",   # 要查詢的資料庫名稱
        charset="utf8"    # 資料庫編碼
    )

def getKeyWords(sql, col_name):
    mycursor = mydb.cursor()
    
    if sql:
        mycursor.execute(sql)
        results = mycursor.fetchall()
        
        total = mycursor.rowcount
        
        if total > 1:
            #change SQL result to dictionary
            columns = [column[0] for column in mycursor.description]
            results = []
            for row in myresult:
                results.append(dict(zip(columns, row)))

            #for result in results:

# 查詢資料庫的函數
def selectData(fun, value):
    mycursor = mydb.cursor()
    sql1 = ""
    if fun == 1:   # 輸入 1 依據作者資訊做模糊查詢
        mycursor.execute("SELECT * FROM artdata where author like '%"+value+"%'")
        sql1 = "SELECT DISTINCT author FROM artdata WHERE author like '%"+value+"%'"
        col_name = "author"
        myresult = mycursor.fetchall()
    elif fun == 2: # 輸入 2 依據作品名稱做模糊查詢
        mycursor.execute("SELECT * FROM artdata where art_name like '%"+value+"%'")
        sql1 = "SELECT DISTINCT art_name FROM artdata WHERE art_name like '%"+value+"%'"
        col_name = "art_name"
        myresult = mycursor.fetchall()
    elif fun == 3: # 輸入 3 依據作品材質做模糊查詢
        mycursor.execute("SELECT * FROM artdata where material like '%"+value+"%'")
        sql1 = "SELECT DISTINCT material FROM artdata WHERE material like '%"+value+"%'"
        col_name = "material"
        myresult = mycursor.fetchall()
    
    # for x in myresult: # 將查詢到的資訊輸入到 console
        # print("編號:",x[2], "作品名稱:",x[1], "作者:", x[3], "年份:", x[4], "尺寸:", x[5], "材質:", x[6])
    
    total = mycursor.rowcount 
    
    if total > 1:
        #change SQL result to dictionary
        columns = [column[0] for column in mycursor.description]
        results = []
        for row in myresult:
            results.append(dict(zip(columns, row)))

        for result in results:
            printArtData(result)
                   
        
        print(line_split)
        print("查詢結果:    {}".format(total))
        print("輸入 1 - 取得相關")
        
        
    else:
        
        print("沒有結果\n")

def getSimilarNumber(number):
    if number:        
        temp = str(number).strip()
        mycursor = mydb.cursor()
        sql = "SELECT * FROM artdata where number like '%"+temp+"%'"
        mycursor.execute(sql)
        myresult = mycursor.fetchall()
        
        total = mycursor.rowcount 
        
        if total > 1:
            #change SQL result to dictionary
            columns = [column[0] for column in mycursor.description]
            results = []
            for row in myresult:
                results.append(dict(zip(columns, row)))
            
            for result in results:
                db_art_name = str(result["art_name"]).strip()
                db_number = str(result["number"]).strip()
                print(line_split)
                print("作品名稱:    {}\n編號:   {}".format(db_art_name,db_number))
                
            print("\n查詢結果:    {}\n".format(total))
            print(line_split)
            print("請輸入正確編號以取得圖片:")
            data = input() # Input number
            getSimilarNumber(data)
            
        else:
            columns = [column[0] for column in mycursor.description]
            results = []
            for row in myresult:
                results.append(dict(zip(columns, row)))
            
            for result in results:

                db_image=base64.b64decode(result['image'])
                file_like=io.BytesIO(db_image)
                img=PIL.Image.open(file_like)
                img.show()
                
                printArtData(result)
        
     

def printArtData(result):
    if result:        
        art_name = str(result["art_name"]).strip()
        number = str(result["number"]).strip()
        author = str(result["author"]).strip()
        year = str(result["year"]).strip()
        size = str(result["size"]).strip()
        material = str(result["material"]).strip()
         
        print(line_split)
        print("作品名稱:    {}".format(art_name))
        print("編號:   {}".format(number))
        print("作者:   {}".format(author))
        print("年份:   {}".format(year))
        print("尺寸:   {}".format(size))
        print("材質:   {}".format(material))

def check_user_input(data):
    try:
        # Convert it into integer
        val = int(data)
    except ValueError:
        print("輸入錯誤。 (輸入 : {})".format(data))

#Main
while True:
    print(line_new)    
    print("===== 歡迎來到世界名畫資料庫 =====")
    print(line_new)
    print("功能介紹")
    print("輸入1 - 依作者名稱查詢(模糊查詢)")
    print("輸入2 - 依作品名稱查詢(模糊查詢)")
    print("輸入3 - 依作品材質查詢(模糊查詢)")
    print("輸入4 - 查詢編號取得圖片")
    print("輸入9 - 退出")
    print(line_new)
    print("==================================")    
    
    user_input = input("\n請輸入:") # 接收使用者需要進入的功能
    if user_input == '1':    
        data = input("請輸入作者名稱:") # 輸入作者名稱
        selectData(1, data) # 依據使用者輸入的作者資訊丟到 selectData 函數查詢結果 
    elif user_input == '2':  
        data = input("請輸入作品名稱:") # 輸入作品名稱
        selectData(2, data) # 依據使用者輸入的作品資訊丟到 selectData 函數查詢結果 
    elif user_input == '3':  
        data = input("請輸入作品材質:") # 輸入作品材質
        selectData(3, data) # 依據使用者輸入的材質資訊丟到 selectData 函數查詢結果
    elif user_input == '4':  
        data = input("請輸入查詢編號:") # Input number
        getSimilarNumber(data) 
    elif user_input == '9': # 離開查詢功能介面
        print("bye! bye!")
        break
    else: # 輸入錯誤，從迴圈從頭再開始
        check_user_input(user_input)
# Out:
# ===== 歡迎來到世界名畫資料庫 =====
#
#
# 功能介紹
# 輸入1 - 依作者名稱查詢(模糊查詢)
# 輸入2 - 依作品名稱查詢(模糊查詢)
# 輸入3 - 依作品材質查詢(模糊查詢)
# 輸入4 - 查詢編號取得圖片
# 輸入9 - 退出
#
#
# ==================================
#
# 請輸入:1
# 請輸入作者名稱:齊白石
# 沒有結果
#
#
#
# ===== 歡迎來到世界名畫資料庫 =====
#
#
# 功能介紹
# 輸入1 - 依作者名稱查詢(模糊查詢)
# 輸入2 - 依作品名稱查詢(模糊查詢)
# 輸入3 - 依作品材質查詢(模糊查詢)
# 輸入4 - 查詢編號取得圖片
# 輸入9 - 退出
#
#
# ==================================
#
# 請輸入:1
# 請輸入作者名稱:安格爾
# ------------------------------------------------
# 作品名稱:    大宮女 La Grand Odalisque
# 編號:   Ingres036
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1814
# 尺寸:   91 x 162 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    泉 The Source
# 編號:   Ingres038
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1856
# 尺寸:   163 x 80 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    荷馬禮贊 Apotheosis of Homer
# 編號:   Ingres046
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1827
# 尺寸:   386 x 515 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    王座上的拿破崙一世 Napoleon I on the throne
# 編號:   Ingres042
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1814
# 尺寸:   260 x 163 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    土耳其浴室 The Turkish Bath
# 編號:   Ingres041
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1862
# 尺寸:   110 x 110 cm
# 材質:   油彩．畫板 Oil on panel
# ------------------------------------------------
# 作品名稱:    小浴女 The Small Bather
# 編號:   Ingres015
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1828
# 尺寸:   35 x 27 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    浴女 The Bather
# 編號:   Ingres039
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1808
# 尺寸:   34 x 22.8 cm
# 材質:   水彩．紙 Watercolour on paper
# ------------------------------------------------
# 作品名稱:    褒格麗公主 Princesse de Broglie
# 編號:   Ingres030
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1851 - 53
# 尺寸:   121.3 x 90.8 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    聖女貞德在雷姆斯教堂裡的查理七世加冕典禮 St. Joan of Arc at the Coronation of Charles VII in Rheims Cathedral
# 編號:   Ingres021
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1854
# 尺寸:   240 x 178 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    羅傑解救安潔莉卡 Angelica saved by Ruggiero
# 編號:   Ingres043
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1819 - 39
# 尺寸:   48 x 40 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    弗朗西斯一世與臨終的達文西 Francis I Receives the Last Breaths of Leonardo da Vinci
# 編號:   Ingres020
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1818
# 尺寸:   40 x 50.5 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    聖瑪麗夫人肖像 Portrait of Madame Marcotte de Sainte-Marie
# 編號:   Ingres005
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1826
# 尺寸:   93 x 74 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    里維拉小姐畫像 Mademoiselle Riviere
# 編號:   Ingres013
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1806
# 尺寸:   100 x 70 cm
# 材質:   油彩．畫布．畫板 Oil on canvas laid down on panel
# ------------------------------------------------
# 作品名稱:    保羅和法蘭西斯科 Paolo and Francesca
# 編號:   Ingres047
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1819
# 尺寸:   480 x 390 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    賈貴路易士．雷布蘭克夫人 Madame Jacques-Louis Leblanc
# 編號:   Ingres026
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1823
# 尺寸:   119.4 x 92.7 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    維納斯 Venus Anadyomene
# 編號:   Ingres049
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1808 - 48
# 尺寸:   163 x 92 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    露意絲女伯爵 Louise de Broglie. Countesse d ’Haussonville
# 編號:   Ingres037
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1845
# 尺寸:   131.8 x 92 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    尼古拉．戈列夫伯爵肖像 Portrait of Count Nikolay Gouriev
# 編號:   Ingres008
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1821
# 尺寸:   86 x 107 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    在西斯汀禮拜堂的教皇仳護七世 Pope Pius VII in the Sistine Chapel
# 編號:   Ingres035
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1814
# 尺寸:   74.5 x 92.7 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    莫蒂西爾夫人 Madame Moitessier
# 編號:   Ingres010
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1856
# 尺寸:   120 x 92.1 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    女子肖像 Portrait of Mme Duvaucey
# 編號:   Ingres048
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1807
# 尺寸:   76.2 x 58.42 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    伊迪帕斯和獅身人面像 Oedipus and the Sphinx
# 編號:   Ingres012
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1826
# 尺寸:   178 x 137 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    洛哲營救安吉莉卡 Angelica saved by Ruggiero
# 編號:   Ingres003
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1819
# 尺寸:   147 x 190 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    聖母崇拜 The Virgin Adoring the Host
# 編號:   Ingres044
# 作者:   安格爾 Jean Auguste Dominique Ingres
# 年份:   1852
# 尺寸:   40.3 x 32.7 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 查詢結果:    24
# 輸入 1 - 取得相關
#
#
# ===== 歡迎來到世界名畫資料庫 =====
#
#
# 功能介紹
# 輸入1 - 依作者名稱查詢(模糊查詢)
# 輸入2 - 依作品名稱查詢(模糊查詢)
# 輸入3 - 依作品材質查詢(模糊查詢)
# 輸入4 - 查詢編號取得圖片
# 輸入9 - 退出
#
#
# ==================================
#
# 請輸入:1
# 請輸入作者名稱:畢卡索
# 沒有結果
#
#
#
# ===== 歡迎來到世界名畫資料庫 =====
#
#
# 功能介紹
# 輸入1 - 依作者名稱查詢(模糊查詢)
# 輸入2 - 依作品名稱查詢(模糊查詢)
# 輸入3 - 依作品材質查詢(模糊查詢)
# 輸入4 - 查詢編號取得圖片
# 輸入9 - 退出
#
#
# ==================================
#
# 請輸入:1
# 請輸入作者名稱:米勒
# ------------------------------------------------
# 作品名稱:    拾穗 Les Gleanuses Salon (The Gleaners)
# 編號:   Millet001
# 作者:   米勒 Jean Francois Millet
# 年份:   1857
# 尺寸:   83.5 x 111 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    晚禱 The Angelus
# 編號:   Millet002
# 作者:   米勒 Jean Francois Millet
# 年份:   1857 - 59
# 尺寸:   55 x 66 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    牧羊女與羊群 Shepherdess with her Flock
# 編號:   Millet003
# 作者:   米勒 Jean Francois Millet
# 年份:   1864
# 尺寸:   81 x 101 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    沐浴的放鵝少女 Geese girls bathing
# 編號:   Millet012
# 作者:   米勒 Jean Francois Millet
# 年份:   1863
# 尺寸:   38 x 46.5 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    春 Spring
# 編號:   Millet091
# 作者:   米勒 Jean Francois Millet
# 年份:   1868 - 73
# 尺寸:   86 x 111 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    播種者 The Sower
# 編號:   Millet073
# 作者:   米勒 Jean Francois Millet
# 年份:   1850
# 尺寸:   101.6 x 82.6 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    星夜 Starry Night
# 編號:   Millet060
# 作者:   米勒 Jean Francois Millet
# 年份:   1850 - 65
# 尺寸:   65.4 x 81.3 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    報春花 Primroses
# 編號:   Millet051
# 作者:   米勒 Jean Francois Millet
# 年份:   1867 - 68
# 尺寸:   40.3 x 47.9 cm
# 材質:   粉蠟．紙 Pastel on paper
# ------------------------------------------------
# 作品名稱:    第一步 First Steps
# 編號:   Millet026
# 作者:   米勒 Jean Francois Millet
# 年份:   1858
# 尺寸:   32.39 x 43.18 cm
# 材質:   粉蠟．紙 Pastel on paper
# ------------------------------------------------
# 作品名稱:    母親和小孩 Mother and Child
# 編號:   Millet031
# 作者:   米勒 Jean Francois Millet
# 年份:   1846 - 48
# 尺寸:   40.6 x 32.7 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    男子畫像 Portrait of a Man
# 編號:   Millet090
# 作者:   米勒 Jean Francois Millet
# 年份:   1845
# 尺寸:   40.6 x 32.3 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    月光下的羊欄 The Sheepfold. Moonlight
# 編號:   Millet022
# 作者:   米勒 Jean Francois Millet
# 年份:   1856 - 60
# 尺寸:   45.5 x 63.18 cm
# 材質:   油彩．畫板 Oil on panel
# ------------------------------------------------
# 作品名稱:    午睡 Noonday Rest
# 編號:   Millet045
# 作者:   米勒 Jean Francois Millet
# 年份:   1866
# 尺寸:   29.2 x 41.9 cm
# 材質:   粉蠟．紙 Pastel on paper
# ------------------------------------------------
# 作品名稱:    秋天乾草堆 Haystacks: Autumn
# 編號:   Millet083
# 作者:   米勒 Jean Francois Millet
# 年份:   1874
# 尺寸:   85.1 x 110.2 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    提水的女孩 Girl carrying water
# 編號:   Millet005
# 作者:   米勒 Jean Francois Millet
# 年份:   1856
# 尺寸:   41 x 33 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    一個男人肖像 Portrait of a Man
# 編號:   Millet014
# 作者:   米勒 Jean Francois Millet
# 年份:   1840 - 41
# 尺寸:   59 x 47 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    養鵝小女孩 Little Goose Girl
# 編號:   Millet039
# 作者:   米勒 Jean Francois Millet
# 年份:   1868
# 尺寸:   41.9 x 52.1 cm
# 材質:   粉蠟．紙 Pastel on paper
# ------------------------------------------------
# 作品名稱:    蒲公英 Dandelions
# 編號:   Millet027
# 作者:   米勒 Jean Francois Millet
# 年份:   1867 - 68
# 尺寸:   40.6 x 50.2 cm
# 材質:   粉蠟．紙 Pastel on paper
# ------------------------------------------------
# 作品名稱:    母親的細心 The Maternal Precaution
# 編號:   Millet030
# 作者:   米勒 Jean Francois Millet
# 年份:   1855 - 57
# 尺寸:   29 x 20.5 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    休息中的收割者 Harvesters Resting (Ruth and Boaz)
# 編號:   Millet033
# 作者:   米勒 Jean Francois Millet
# 年份:   1850 - 53
# 尺寸:   67.3 x 119.7 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    牧羊人撫育他的羊群 Shepherd Tending His Flock
# 編號:   Millet009
# 作者:   米勒 Jean Francois Millet
# 年份:   1860
# 尺寸:   81.8 x 100.5 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    播種者 The Sower
# 編號:   Millet087
# 作者:   米勒 Jean Francois Millet
# 年份:   1865 - 1866
# 尺寸:   47.1 x 37.5 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    強風 The Gust of Wind
# 編號:   Millet016
# 作者:   米勒 Jean Francois Millet
# 年份:   1871 - 73
# 尺寸:   90.5 x 117.5 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 作品名稱:    哺喂 La Becquée
# 編號:   Millet040
# 作者:   米勒 Jean Francois Millet
# 年份:   1860
# 尺寸:   41 x 34 cm
# 材質:   油彩．畫布 Oil on Canvas
# ------------------------------------------------
# 查詢結果:    24
# 輸入 1 - 取得相關
#
#
# ===== 歡迎來到世界名畫資料庫 =====
#
#
# 功能介紹
# 輸入1 - 依作者名稱查詢(模糊查詢)
# 輸入2 - 依作品名稱查詢(模糊查詢)
# 輸入3 - 依作品材質查詢(模糊查詢)
# 輸入4 - 查詢編號取得圖片
# 輸入9 - 退出
#
#
# ==================================
# 請輸入:1
# 請輸入作者名稱:雷諾瓦
# 沒有結果
#
#
#
# ===== 歡迎來到世界名畫資料庫 =====
#
#
# 功能介紹
# 輸入1 - 依作者名稱查詢(模糊查詢)
# 輸入2 - 依作品名稱查詢(模糊查詢)
# 輸入3 - 依作品材質查詢(模糊查詢)
# 輸入4 - 查詢編號取得圖片
# 輸入9 - 退出
#
#
# ==================================
#
# 請輸入:9
# bye! bye!

# %%
#編號 Cimabue003
#  米勒 米開朗基羅
